# %%
# %pip install openai
# %pip install gpt_index
# %pip install langchain
# %pip install gradio
# %pip install python-pptx
# %pip install torch
# %pip install transformers
# %pip install docx2txt
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openai in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (0.27.2)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from openai) (4.64.0)
# Requirement already satisfied: aiohttp in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from openai) (3.8.4)
# Requirement already satisfied: requests>=2.20 in c:\programdata\anaconda3\lib\site-packages (from openai) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->openai) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->openai) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->openai) (1.26.9)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai) (5.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai) (1.6.3)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai) (4.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\programdata\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp->openai) (4.1.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->openai) (0.4.4)
#
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gpt_index in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (0.4.33)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from gpt_index) (1.21.5)
# Requirement already satisfied: langchain in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gpt_index) (0.0.117)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from gpt_index) (1.4.2)
# Requirement already satisfied: tiktoken in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gpt_index) (0.3.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gpt_index) (8.2.2)
# Requirement already satisfied: openai>=0.26.4 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gpt_index) (0.27.2)
# Requirement already satisfied: dataclasses-json in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gpt_index) (0.5.7)
# Requirement already satisfied: aiohttp in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from openai>=0.26.4->gpt_index) (3.8.4)
# Requirement already satisfied: requests>=2.20 in c:\programdata\anaconda3\lib\site-packages (from openai>=0.26.4->gpt_index) (2.27.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from openai>=0.26.4->gpt_index) (4.64.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->openai>=0.26.4->gpt_index) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->openai>=0.26.4->gpt_index) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->openai>=0.26.4->gpt_index) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->openai>=0.26.4->gpt_index) (2021.10.8)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai>=0.26.4->gpt_index) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai>=0.26.4->gpt_index) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai>=0.26.4->gpt_index) (1.6.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai>=0.26.4->gpt_index) (5.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai>=0.26.4->gpt_index) (4.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai>=0.26.4->gpt_index) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\programdata\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp->openai>=0.26.4->gpt_index) (4.1.1)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from dataclasses-json->gpt_index) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from dataclasses-json->gpt_index) (0.8.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from dataclasses-json->gpt_index) (3.19.0)
# Requirement already satisfied: packaging>=17.0 in c:\programdata\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json->gpt_index) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.3.0->dataclasses-json->gpt_index) (3.0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect>=0.4.0->dataclasses-json->gpt_index) (0.4.3)
# Requirement already satisfied: pydantic<2,>=1 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from langchain->gpt_index) (1.10.2)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\programdata\anaconda3\lib\site-packages (from langchain->gpt_index) (6.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: SQLAlchemy<2,>=1 in c:\programdata\anaconda3\lib\site-packages (from langchain->gpt_index) (1.4.32)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from SQLAlchemy<2,>=1->langchain->gpt_index) (1.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->gpt_index) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->gpt_index) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->gpt_index) (1.16.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\programdata\anaconda3\lib\site-packages (from tiktoken->gpt_index) (2022.3.15)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->openai>=0.26.4->gpt_index) (0.4.4)
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (0.0.117)
# Requirement already satisfied: numpy<2,>=1 in c:\programdata\anaconda3\lib\site-packages (from langchain) (1.21.5)
# Requirement already satisfied: SQLAlchemy<2,>=1 in c:\programdata\anaconda3\lib\site-packages (from langchain) (1.4.32)
# Requirement already satisfied: pydantic<2,>=1 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from langchain) (1.10.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from langchain) (0.5.7)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from langchain) (3.8.4)
# Requirement already satisfied: requests<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from langchain) (2.27.1)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\programdata\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from langchain) (8.2.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (4.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.6.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (5.1.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\programdata\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp<4.0.0,>=3.8.3->langchain) (4.1.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.8.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (1.5.1)
# Requirement already satisfied: packaging>=17.0 in c:\programdata\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from SQLAlchemy<2,>=1->langchain) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (0.4.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gradio in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (3.22.1)
# Requirement already satisfied: altair>=4.2.0 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (4.2.2)
# Requirement already satisfied: uvicorn in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (0.21.1)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from gradio) (3.5.1)
# Requirement already satisfied: ffmpy in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (0.3.0)
# Requirement already satisfied: websockets>=10.0 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (10.4)
# Requirement already satisfied: python-multipart in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from gradio) (1.4.2)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from gradio) (2022.2.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from gradio) (1.21.5)
# Requirement already satisfied: markupsafe in c:\programdata\anaconda3\lib\site-packages (from gradio) (2.0.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from gradio) (2.27.1)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (2.2.0)
# Requirement already satisfied: pydantic in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (1.10.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: aiohttp in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (3.8.4)
# Requirement already satisfied: huggingface-hub>=0.13.0 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: pydub in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (0.3.3)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: orjson in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (3.8.7)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from gradio) (4.1.1)
# Requirement already satisfied: fastapi in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (0.95.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from gradio) (2.11.3)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from gradio) (9.0.1)
# Requirement already satisfied: aiofiles in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (23.1.0)
# Requirement already satisfied: httpx in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from gradio) (0.23.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\programdata\anaconda3\lib\site-packages (from altair>=4.2.0->gradio) (4.4.0)
# Requirement already satisfied: toolz in c:\programdata\anaconda3\lib\site-packages (from altair>=4.2.0->gradio) (0.11.2)
# Requirement already satisfied: entrypoints in c:\programdata\anaconda3\lib\site-packages (from altair>=4.2.0->gradio) (0.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.13.0->gradio) (4.64.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.13.0->gradio) (3.6.0)
# Requirement already satisfied: packaging>=20.9 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.13.0->gradio) (21.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (21.4.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.0)
# Requirement already satisfied: uc-micro-py in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.13.0->gradio) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->gradio) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->gradio) (1.16.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.13.0->gradio) (0.4.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->gradio) (5.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->gradio) (4.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->gradio) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->gradio) (1.6.3)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->gradio) (1.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->gradio) (2.0.4)
# Requirement already satisfied: idna>=2.0 in c:\programdata\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->gradio) (3.3)
# Requirement already satisfied: starlette<0.27.0,>=0.26.1 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from fastapi->gradio) (0.26.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\programdata\anaconda3\lib\site-packages (from starlette<0.27.0,>=0.26.1->fastapi->gradio) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.27.0,>=0.26.1->fastapi->gradio) (1.2.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx->gradio) (2021.10.8)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from httpx->gradio) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from httpx->gradio) (1.5.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio) (0.14.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->gradio) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->gradio) (1.3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->gradio) (1.26.9)
# Requirement already satisfied: click>=7.0 in c:\programdata\anaconda3\lib\site-packages (from uvicorn->gradio) (8.0.4)
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-pptx in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (0.6.21)
# Requirement already satisfied: lxml>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from python-pptx) (4.8.0)
#
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\programdata\anaconda3\lib\site-packages (from python-pptx) (3.0.3)
# Requirement already satisfied: Pillow>=3.3.2 in c:\programdata\anaconda3\lib\site-packages (from python-pptx) (9.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (2.0.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch) (3.6.0)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch) (2.7.1)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch) (4.1.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch) (2.11.3)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch) (1.10.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (4.27.2)
# Requirement already satisfied: tqdm>=4.27 in c:\programdata\anaconda3\lib\site-packages (from transformers) (4.64.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from transformers) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (from transformers) (0.13.2)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\lib\site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (3.3)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: docx2txt in c:\users\kamranarshad\appdata\roaming\python\python39\site-packages (0.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import openai
openai.organization = ""
openai.api_key = ""
openai.Model.list()

from gpt_index import SimpleDirectoryReader, GPTListIndex, GPTSimpleVectorIndex, LLMPredictor, PromptHelper
from langchain import OpenAI
import gradio as gr
import sys
import os

# %%
os.environ["OPENAI_API_KEY"] = ''

def construct_index(directory_path):
    max_input_size = 4096
    num_outputs = 512
    max_chunk_overlap = 20
    chunk_size_limit = 600

    prompt_helper = PromptHelper(max_input_size, num_outputs, max_chunk_overlap, chunk_size_limit=chunk_size_limit)

    llm_predictor = LLMPredictor(llm=OpenAI(temperature=0.7, model_name="kambot-ai-assistance", max_tokens=num_outputs))

    documents = SimpleDirectoryReader(directory_path).load_data()

    index = GPTSimpleVectorIndex(documents, llm_predictor=llm_predictor, prompt_helper=prompt_helper)

    index.save_to_disk('index.json')

    return index

def chatbot(input_text):
    index = GPTSimpleVectorIndex.load_from_disk('index.json')
    response = index.query(input_text, response_mode="compact")
    return response.response

iface = gr.Interface(fn=chatbot,
                     inputs=gr.inputs.Textbox(lines=7, label="how can I help you?"),
                     outputs="text",
                     title="TA Kamran-bot Assistant")

index = construct_index("docs")
# Out:
# C:\Users\KamranArshad\AppData\Roaming\Python\Python39\site-packages\gradio\inputs.py:27: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# C:\Users\KamranArshad\AppData\Roaming\Python\Python39\site-packages\gradio\deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# C:\Users\KamranArshad\AppData\Roaming\Python\Python39\site-packages\gradio\deprecation.py:40: UserWarning: `numeric` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# INFO:gpt_index.token_counter.token_counter:> [build_index_from_documents] Total LLM token usage: 0 tokens
# INFO:gpt_index.token_counter.token_counter:> [build_index_from_documents] Total embedding token usage: 584017 tokens

# %%
iface.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7861
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# INFO:gpt_index.token_counter.token_counter:> [query] Total LLM token usage: 154 tokens
# INFO:gpt_index.token_counter.token_counter:> [query] Total embedding token usage: 9 tokens
# INFO:gpt_index.token_counter.token_counter:> [query] Total LLM token usage: 143 tokens
# INFO:gpt_index.token_counter.token_counter:> [query] Total embedding token usage: 8 tokens
# INFO:gpt_index.token_counter.token_counter:> [query] Total LLM token usage: 796 tokens
# INFO:gpt_index.token_counter.token_counter:> [query] Total embedding token usage: 15 tokens
